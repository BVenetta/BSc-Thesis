# %%
import templater3
import re
import nltk  
import string
from nltk.corpus import stopwords

# %%
line = open('simplewiki-20211120-lists-1k.tsv').readlines()[0]
page, code = line.split('\t')

# template = templater3.Templater(min_block_size=2)
# for line in code.replace('\\n', '\n').splitlines():
#     template .learn(line)
# template._template

# %%
def temp(c):
    template = templater3.Templater(min_block_size=2)
    for line in c:
        template.learn(line)
    return template

# %%
template = temp(code.replace('\\n', '\n').splitlines())

# %%
parsed = [template.parse(line) for line in code.replace('\\n', '\n').splitlines()]
columns = list(zip(*parsed))
# for column in columns:
#     print(set(column))

# %%
func = lambda c: c.endswith(')')

def split_set(cells, func):
    c1 = [c for c in cells if func(c)]
    c2 = [c for c in cells if not func(c)]
    return c1, c2

c1, c2 = split_set(columns[-1], func)

# %%
c1template = temp(c1)
c2template = temp(c2)

# %%
print(c1template._template)
print(c2template._template)
# Out:
# [None, '[[', None, ']]', None]
# [None]

# %%
c1template = templater3.Templater(min_block_size=2)
for line in c1:
    c1template.learn(line)
c1template._template
# Out:
# [None, '[[', None, ']]', None]

# %%
c2template = templater3.Templater(min_block_size=2)
for line in c2:
    c2template.learn(line)
c2template._template
# Out:
# [None]

# %%
english_stopwords = stopwords.words('english')
set_english_stopwords = set(english_stopwords)

# %%
c1 = str(c1)
c2 = str(c2)

# %%
# def stopword(x):    
#     without_stopwords = []
    
#     a_sentence = re.findall(r"\w+|[^\w\s]", x, re.UNICODE)

#     for token in a_sentence:
#         if token not in set_english_stopwords:
#             without_stopwords.append(token)
    
#     return a_sentence

# def capital(x):
    
#     cap = re.split('(?<=.)(?=[A-Z])', x)
    
#     return cap


# def grammar(x):
    
#     punc = re.split('([' + re.escape(string.punctuation) + '])', x)
    
#     return punc

# %%
def process_text(x):
    # capitals 
    cap = re.split('(?<=.)(?=[A-Z])', x)
    
    # punctuation
    punc = re.split('([' + re.escape(string.punctuation) + '])', x)
    
    # stop words
    without_stopwords = []
    a_sentence = []
    
    for match in re.finditer(r'[^.,?!\s]+|[.,?!]', x):
        a_sentence.append(match.group())

    for token in a_sentence:
        if token not in set_english_stopwords:
            without_stopwords.append(token)
    
    return cap, punc, without_stopwords

# %%
process_text(c2)
# Out:
# (['["[[',
#   'April ',
#   "Fools' ",
#   'Day]]", "',
#   'International ',
#   "Children's ",
#   'Book ',
#   'Day", \'[[',
#   'Thailand|',
#   'Thai]] ',
#   'Heritage and [[wikt:conservation|',
#   'Conservation]] ',
#   "Day', '",
#   'World [[',
#   'Autism]] ',
#   'Awareness ',
#   "Day', '",
#   'International ',
#   'Day for ',
#   'Landmine ',
#   'Awareness and ',
#   "Assistance', '",
#   'World [[',
#   'Health]] ',
#   "Day', '",
#   'Day of the [[',
#   'Finnish language]]\', "[[',
#   "Cosmonaut]]s' ",
#   'Day ([[',
#   'Russia]]), marking the day of [[',
#   'Yuri ',
#   'Gagarin]]\'s space flight", \'',
#   'Songkan ([[',
#   'Laos]]), local ',
#   'New ',
#   "Year celebration', '[[",
#   'Cambodia]]n ',
#   'New ',
#   "Year', '[[",
#   'Southeast ',
#   'Asia]]n [[',
#   'New ',
#   'Year]] festivals, including [[',
#   "Songkran]]', '[[",
#   'Georgian language]] ',
#   "Day', '",
#   'Pan-',
#   'American ',
#   "Day', '[[",
#   'Birthday]] of ',
#   'Queen [[',
#   'Margrethe ',
#   'I',
#   'I of ',
#   "Denmark]]', '",
#   'World [[',
#   'Voice]] ',
#   "Day', '",
#   'National ',
#   'Day of [[',
#   "Syria]]', '",
#   'World [[',
#   'Hemophilia]] ',
#   "Day', '",
#   'International ',
#   'Day of [[',
#   'Monument]]s and ',
#   "Sites', '[[",
#   'Bicycle]] ',
#   "Day', '",
#   'Dutch-',
#   'American ',
#   'Friendship ',
#   "Day', '[[",
#   'Birthday]] of ',
#   'King [[',
#   'Mswati ',
#   'I',
#   'I',
#   'I]] of [[',
#   "Swaziland]]', '4/20 in [[",
#   'Cannabis]] [[',
#   "Culture]]', '[[",
#   'Earth ',
#   "Day]]', '",
#   'World [[',
#   'Book]] ',
#   "Day', '[[",
#   'Australia]] and [[',
#   'New ',
#   'Zealand]] celebrate [[',
#   'A',
#   'N',
#   'Z',
#   'A',
#   'C ',
#   'Day]]. [http://www.awm.gov.au/dawn/spirit/meaning.asp ',
#   'A',
#   'N',
#   'Z',
#   'A',
#   'C] {{',
#   'Webarchive|url=https://web.archive.org/web/20060615053606/http://www.awm.gov.au/dawn/spirit/meaning.asp |date=2006-06-15 }} means ',
#   'Australian and ',
#   'New ',
#   'Zealand ',
#   'Army ',
#   "Corps, and began in 1915.', '",
#   'World [[',
#   'D',
#   'N',
#   'A]] ',
#   "Day', '",
#   'World [[',
#   'Malaria]] ',
#   "Day', '",
#   'World [[',
#   'Tapir]] ',
#   'Day\', "',
#   "King's ",
#   'Day ([[',
#   'Netherlands]]) from [[2014]], birthday of [[',
#   'Willem-',
#   'Alexander of the ',
#   'Netherlands]]", \'',
#   'Workers ',
#   'Memorial ',
#   "Day', '",
#   'Showa ',
#   'Day ([[',
#   'Japan]]), birthday of ',
#   'Emperor [[',
#   "Hirohito]], who died in [[1989]]', '",
#   'International [[',
#   'Dance]] ',
#   'Day\', "',
#   'Former ',
#   "Queen's ",
#   'Day ',
#   'Holiday in the [[',
#   'Netherlands]] (changed to ',
#   "King's ",
#   'Day, [[',
#   'April 27]] in [[2014]]), was the birthday of former ',
#   'Queen [[',
#   'Juliana of the ',
#   'Netherlands]]", \'',
#   'International [[',
#   'Jazz]] ',
#   "Day']"],
#  ['',
#   '[',
#   '',
#   '"',
#   '',
#   '[',
#   '',
#   '[',
#   'April Fools',
#   "'",
#   ' Day',
#   ']',
#   '',
#   ']',
#   '',
#   '"',
#   '',
#   ',',
#   ' ',
#   '"',
#   'International Children',
#   "'",
#   's Book Day',
#   '"',
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Thailand',
#   '|',
#   'Thai',
#   ']',
#   '',
#   ']',
#   ' Heritage and ',
#   '[',
#   '',
#   '[',
#   'wikt',
#   ':',
#   'conservation',
#   '|',
#   'Conservation',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'World ',
#   '[',
#   '',
#   '[',
#   'Autism',
#   ']',
#   '',
#   ']',
#   ' Awareness Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'International Day for Landmine Awareness and Assistance',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'World ',
#   '[',
#   '',
#   '[',
#   'Health',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'Day of the ',
#   '[',
#   '',
#   '[',
#   'Finnish language',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   '"',
#   '',
#   '[',
#   '',
#   '[',
#   'Cosmonaut',
#   ']',
#   '',
#   ']',
#   's',
#   "'",
#   ' Day ',
#   '(',
#   '',
#   '[',
#   '',
#   '[',
#   'Russia',
#   ']',
#   '',
#   ']',
#   '',
#   ')',
#   '',
#   ',',
#   ' marking the day of ',
#   '[',
#   '',
#   '[',
#   'Yuri Gagarin',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   's space flight',
#   '"',
#   '',
#   ',',
#   ' ',
#   "'",
#   'Songkan ',
#   '(',
#   '',
#   '[',
#   '',
#   '[',
#   'Laos',
#   ']',
#   '',
#   ']',
#   '',
#   ')',
#   '',
#   ',',
#   ' local New Year celebration',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Cambodia',
#   ']',
#   '',
#   ']',
#   'n New Year',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Southeast Asia',
#   ']',
#   '',
#   ']',
#   'n ',
#   '[',
#   '',
#   '[',
#   'New Year',
#   ']',
#   '',
#   ']',
#   ' festivals',
#   ',',
#   ' including ',
#   '[',
#   '',
#   '[',
#   'Songkran',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Georgian language',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'Pan',
#   '-',
#   'American Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Birthday',
#   ']',
#   '',
#   ']',
#   ' of Queen ',
#   '[',
#   '',
#   '[',
#   'Margrethe II of Denmark',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'World ',
#   '[',
#   '',
#   '[',
#   'Voice',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'National Day of ',
#   '[',
#   '',
#   '[',
#   'Syria',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'World ',
#   '[',
#   '',
#   '[',
#   'Hemophilia',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'International Day of ',
#   '[',
#   '',
#   '[',
#   'Monument',
#   ']',
#   '',
#   ']',
#   's and Sites',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Bicycle',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'Dutch',
#   '-',
#   'American Friendship Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Birthday',
#   ']',
#   '',
#   ']',
#   ' of King ',
#   '[',
#   '',
#   '[',
#   'Mswati III',
#   ']',
#   '',
#   ']',
#   ' of ',
#   '[',
#   '',
#   '[',
#   'Swaziland',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '4',
#   '/',
#   '20 in ',
#   '[',
#   '',
#   '[',
#   'Cannabis',
#   ']',
#   '',
#   ']',
#   ' ',
#   '[',
#   '',
#   '[',
#   'Culture',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Earth Day',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'World ',
#   '[',
#   '',
#   '[',
#   'Book',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   '',
#   '[',
#   '',
#   '[',
#   'Australia',
#   ']',
#   '',
#   ']',
#   ' and ',
#   '[',
#   '',
#   '[',
#   'New Zealand',
#   ']',
#   '',
#   ']',
#   ' celebrate ',
#   '[',
#   '',
#   '[',
#   'ANZAC Day',
#   ']',
#   '',
#   ']',
#   '',
#   '.',
#   ' ',
#   '[',
#   'http',
#   ':',
#   '',
#   '/',
#   '',
#   '/',
#   'www',
#   '.',
#   'awm',
#   '.',
#   'gov',
#   '.',
#   'au',
#   '/',
#   'dawn',
#   '/',
#   'spirit',
#   '/',
#   'meaning',
#   '.',
#   'asp ANZAC',
#   ']',
#   ' ',
#   '{',
#   '',
#   '{',
#   'Webarchive',
#   '|',
#   'url',
#   '=',
#   'https',
#   ':',
#   '',
#   '/',
#   '',
#   '/',
#   'web',
#   '.',
#   'archive',
#   '.',
#   'org',
#   '/',
#   'web',
#   '/',
#   '20060615053606',
#   '/',
#   'http',
#   ':',
#   '',
#   '/',
#   '',
#   '/',
#   'www',
#   '.',
#   'awm',
#   '.',
#   'gov',
#   '.',
#   'au',
#   '/',
#   'dawn',
#   '/',
#   'spirit',
#   '/',
#   'meaning',
#   '.',
#   'asp ',
#   '|',
#   'date',
#   '=',
#   '2006',
#   '-',
#   '06',
#   '-',
#   '15 ',
#   '}',
#   '',
#   '}',
#   ' means Australian and New Zealand Army Corps',
#   ',',
#   ' and began in 1915',
#   '.',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'World ',
#   '[',
#   '',
#   '[',
#   'DNA',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'World ',
#   '[',
#   '',
#   '[',
#   'Malaria',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'World ',
#   '[',
#   '',
#   '[',
#   'Tapir',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   '"',
#   'King',
#   "'",
#   's Day ',
#   '(',
#   '',
#   '[',
#   '',
#   '[',
#   'Netherlands',
#   ']',
#   '',
#   ']',
#   '',
#   ')',
#   ' from ',
#   '[',
#   '',
#   '[',
#   '2014',
#   ']',
#   '',
#   ']',
#   '',
#   ',',
#   ' birthday of ',
#   '[',
#   '',
#   '[',
#   'Willem',
#   '-',
#   'Alexander of the Netherlands',
#   ']',
#   '',
#   ']',
#   '',
#   '"',
#   '',
#   ',',
#   ' ',
#   "'",
#   'Workers Memorial Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'Showa Day ',
#   '(',
#   '',
#   '[',
#   '',
#   '[',
#   'Japan',
#   ']',
#   '',
#   ']',
#   '',
#   ')',
#   '',
#   ',',
#   ' birthday of Emperor ',
#   '[',
#   '',
#   '[',
#   'Hirohito',
#   ']',
#   '',
#   ']',
#   '',
#   ',',
#   ' who died in ',
#   '[',
#   '',
#   '[',
#   '1989',
#   ']',
#   '',
#   ']',
#   '',
#   "'",
#   '',
#   ',',
#   ' ',
#   "'",
#   'International ',
#   '[',
#   '',
#   '[',
#   'Dance',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ',',
#   ' ',
#   '"',
#   'Former Queen',
#   "'",
#   's Day Holiday in the ',
#   '[',
#   '',
#   '[',
#   'Netherlands',
#   ']',
#   '',
#   ']',
#   ' ',
#   '(',
#   'changed to King',
#   "'",
#   's Day',
#   ',',
#   ' ',
#   '[',
#   '',
#   '[',
#   'April 27',
#   ']',
#   '',
#   ']',
#   ' in ',
#   '[',
#   '',
#   '[',
#   '2014',
#   ']',
#   '',
#   ']',
#   '',
#   ')',
#   '',
#   ',',
#   ' was the birthday of former Queen ',
#   '[',
#   '',
#   '[',
#   'Juliana of the Netherlands',
#   ']',
#   '',
#   ']',
#   '',
#   '"',
#   '',
#   ',',
#   ' ',
#   "'",
#   'International ',
#   '[',
#   '',
#   '[',
#   'Jazz',
#   ']',
#   '',
#   ']',
#   ' Day',
#   "'",
#   '',
#   ']',
#   ''],
#  ['["[[April',
#   "Fools'",
#   'Day]]"',
#   ',',
#   '"International',
#   "Children's",
#   'Book',
#   'Day"',
#   ',',
#   "'[[Thailand|Thai]]",
#   'Heritage',
#   '[[wikt:conservation|Conservation]]',
#   "Day'",
#   ',',
#   "'World",
#   '[[Autism]]',
#   'Awareness',
#   "Day'",
#   ',',
#   "'International",
#   'Day',
#   'Landmine',
#   'Awareness',
#   "Assistance'",
#   ',',
#   "'World",
#   '[[Health]]',
#   "Day'",
#   ',',
#   "'Day",
#   '[[Finnish',
#   "language]]'",
#   ',',
#   '"[[Cosmonaut]]s\'',
#   'Day',
#   '([[Russia]])',
#   ',',
#   'marking',
#   'day',
#   '[[Yuri',
#   "Gagarin]]'s",
#   'space',
#   'flight"',
#   ',',
#   "'Songkan",
#   '([[Laos]])',
#   ',',
#   'local',
#   'New',
#   'Year',
#   "celebration'",
#   ',',
#   "'[[Cambodia]]n",
#   'New',
#   "Year'",
#   ',',
#   "'[[Southeast",
#   'Asia]]n',
#   '[[New',
#   'Year]]',
#   'festivals',
#   ',',
#   'including',
#   "[[Songkran]]'",
#   ',',
#   "'[[Georgian",
#   'language]]',
#   "Day'",
#   ',',
#   "'Pan-American",
#   "Day'",
#   ',',
#   "'[[Birthday]]",
#   'Queen',
#   '[[Margrethe',
#   'II',
#   "Denmark]]'",
#   ',',
#   "'World",
#   '[[Voice]]',
#   "Day'",
#   ',',
#   "'National",
#   'Day',
#   "[[Syria]]'",
#   ',',
#   "'World",
#   '[[Hemophilia]]',
#   "Day'",
#   ',',
#   "'International",
#   'Day',
#   '[[Monument]]s',
#   "Sites'",
#   ',',
#   "'[[Bicycle]]",
#   "Day'",
#   ',',
#   "'Dutch-American",
#   'Friendship',
#   "Day'",
#   ',',
#   "'[[Birthday]]",
#   'King',
#   '[[Mswati',
#   'III]]',
#   "[[Swaziland]]'",
#   ',',
#   "'4/20",
#   '[[Cannabis]]',
#   "[[Culture]]'",
#   ',',
#   "'[[Earth",
#   "Day]]'",
#   ',',
#   "'World",
#   '[[Book]]',
#   "Day'",
#   ',',
#   "'[[Australia]]",
#   '[[New',
#   'Zealand]]',
#   'celebrate',
#   '[[ANZAC',
#   'Day]]',
#   '.',
#   '[http://www',
#   '.',
#   'awm',
#   '.',
#   'gov',
#   '.',
#   'au/dawn/spirit/meaning',
#   '.',
#   'asp',
#   'ANZAC]',
#   '{{Webarchive|url=https://web',
#   '.',
#   'archive',
#   '.',
#   'org/web/20060615053606/http://www',
#   '.',
#   'awm',
#   '.',
#   'gov',
#   '.',
#   'au/dawn/spirit/meaning',
#   '.',
#   'asp',
#   '|date=2006-06-15',
#   '}}',
#   'means',
#   'Australian',
#   'New',
#   'Zealand',
#   'Army',
#   'Corps',
#   ',',
#   'began',
#   '1915',
#   '.',
#   "'",
#   ',',
#   "'World",
#   '[[DNA]]',
#   "Day'",
#   ',',
#   "'World",
#   '[[Malaria]]',
#   "Day'",
#   ',',
#   "'World",
#   '[[Tapir]]',
#   "Day'",
#   ',',
#   '"King\'s',
#   'Day',
#   '([[Netherlands]])',
#   '[[2014]]',
#   ',',
#   'birthday',
#   '[[Willem-Alexander',
#   'Netherlands]]"',
#   ',',
#   "'Workers",
#   'Memorial',
#   "Day'",
#   ',',
#   "'Showa",
#   'Day',
#   '([[Japan]])',
#   ',',
#   'birthday',
#   'Emperor',
#   '[[Hirohito]]',
#   ',',
#   'died',
#   "[[1989]]'",
#   ',',
#   "'International",
#   '[[Dance]]',
#   "Day'",
#   ',',
#   '"Former',
#   "Queen's",
#   'Day',
#   'Holiday',
#   '[[Netherlands]]',
#   '(changed',
#   "King's",
#   'Day',
#   ',',
#   '[[April',
#   '27]]',
#   '[[2014]])',
#   ',',
#   'birthday',
#   'former',
#   'Queen',
#   '[[Juliana',
#   'Netherlands]]"',
#   ',',
#   "'International",
#   '[[Jazz]]',
#   "Day']"])
